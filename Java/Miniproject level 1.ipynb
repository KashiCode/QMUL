// %% [markdown]
// # Miniproject Assessed Exercise
// # Version 1
// # Level D
// ## Maks Ostrynski
// ## Student ID: 230367485
// ## 31/10/23

// %% [markdown]
// ## Summary of the Question:
//
// Write a procedural program that simulates pets that the player must look after.

// %% [markdown]
// ## Justification that the program passes these levels:
//
//
// ### Level 1 – G minus: Getting started: Input-Output
//
// - Includes user Input fields to enter the pet name and interact with the pet.
// - Includes an output menu so users can select what they want to do with their pet.
//
// ### Level 2 – G: Making progress: Assignments and Expressions:
//
// - The program uses variables (petName, hunger, happiness,and interacts with them.
// -  Defines the PetStatus() method which returns whether or not the pet is Alive.
//
// ### Level 3 – F: Getting there: Decisions
//
// - Includes IF, ELSE statements.
// - Defines a method called PetStatus() that takes arguments.
//
// ### Level 4 - D: Bare Pass: Loops
//
// - Uses while loops to loop through each round of the game.

// %% [markdown]
// ## The literate program development:

// %% [markdown]
// ### PetStatus()
//
// #### Functionality
//
// Checks whether the pet is still alive.
//
//
// #### Implementation
// Uses IF, ELSE statements with OR logical operator.

// %%
    // Checks if the pet is still alive. 
    public static boolean PetStatus(int hunger, int happiness, String petName) {
        //If the hunger or happiness is zero then the pet has died. It outputs this to the user. 
        if (hunger <= 0 || happiness <= 0) {
            System.out.println(petName + " has died :(");
            //returns a boolean value of false or true to assign to "alive" variable. 
            return false;
        }
        return true;
    }
}

//END OF PETSTATUS
// Out:
// |   }
// illegal start of statement

// %% [markdown]
// ### PetGame()
//
// #### Functionality
//
// The main part of my program which plays the game. It assigns a happiness and hunger value to a new pet created by the user and then allows the user to interact with the pet either feeding it or playing with it until the pet passes away.
//
//
// #### Implementation
// Uses IF, ELSE statements with AND logical operator. Uses a while loop in order to loop through the program until the user quits or the pet dies.

// %%
   //Main game method. Called by Main args statement. 
    public static void PetGame(){

        //Creates a new scanner object and asks the user input their pet name.
        Scanner scanner = new Scanner(System.in);

        System.out.println("Welcome to the Pet Game!");

        System.out.print("Please enter your pet's name: ");
        String petName = scanner.nextLine();

        //Sets the pets stats of hunger and happiness alongside whether its alive. 
        int hunger = 50;
        int happiness = 50;
        boolean alive = true;

        //sets value of quit to false.
        boolean quit = false;
        //Defines a while loop that runs along as the user doesnt quit and the pet is alive. 
        while (!quit && alive) {

            //Outputs a simple menu of options to the user of how they can interact with their pet. 
            System.out.println("1. Feed " + petName);
            System.out.println("2. Play with " + petName);
            System.out.println("3. Quit");
            System.out.print("Enter your choice: ");

            //Accepts the user input.
            int choice = scanner.nextInt();
            scanner.nextLine();

            //Based on the choices made above the if else statements evaluate what procedure to follow. For feeding the pet hunger is decreased etc
            if (choice == 1) {
                hunger += 10;
                happiness += 5;
                System.out.println(petName + " was fed and is now full and happy!");
            } else if (choice == 2) {
                hunger -= 10;
                happiness += 5;
                System.out.println("You played with " + petName + "!");
            } else if (choice == 3) {
                quit = true;
                System.out.println("Thanks for Playing!");
            } else {
                System.out.println("Invalid choice.");
            }

            // Triggers at the end of each round to ensure the pet hasnt died. Calls the PetStatus function. 
            alive = PetStatus(hunger, happiness, petName);
        }

        //Closes the scanner object. 
        scanner.close();
    }
//END OF PETGAME

// %% [markdown]
// ### Full code:

// %%
/* ***************************************
  @author    Maks
  @date      31 October 2023
  @version   1
  @StudentID: 230367485

  MiniProject: A pet program that creates and allows you to look after a pet. The goal of the game is to keep the pet healthy and happy. 

****************************************/


import java.util.Scanner;

public class Main {
    public static void main(String[] args) {
        //Calls the PetGame method at the start of the program. 
        PetGame();

    }

     //Main game method. Called by Main args statement. 
    public static void PetGame(){

        //Creates a new scanner object and asks the user input their pet name.
        Scanner scanner = new Scanner(System.in);

        System.out.println("Welcome to the Pet Game!");

        System.out.print("Please enter your pet's name: ");
        String petName = scanner.nextLine();

        //Sets the pets stats of hunger and happiness alongside whether its alive. 
        int hunger = 50;
        int happiness = 50;
        boolean alive = true;

        //sets value of quit to false.
        boolean quit = false;
        //Defines a while loop that runs along as the user doesnt quit and the pet is alive. 
        while (!quit && alive) {

            //Outputs a simple menu of options to the user of how they can interact with their pet. 
            System.out.println("1. Feed " + petName);
            System.out.println("2. Play with " + petName);
            System.out.println("3. Quit");
            System.out.print("Enter your choice: ");

            //Accepts the user input.
            int choice = scanner.nextInt();
            scanner.nextLine();

            //Based on the choices made above the if else statements evaluate what procedure to follow. For feeding the pet hunger is decreased etc
            if (choice == 1) {
                hunger += 10;
                happiness += 5;
                System.out.println(petName + " was fed and is now full and happy!");
            } else if (choice == 2) {
                hunger -= 10;
                happiness += 5;
                System.out.println("You played with " + petName + "!");
            } else if (choice == 3) {
                quit = true;
                System.out.println("Thanks for Playing!");
            } else {
                System.out.println("Invalid choice.");
            }

            // Triggers at the end of each round to ensure the pet hasnt died. Calls the PetStatus function. 
            alive = PetStatus(hunger, happiness, petName);
        }

        //Closes the scanner object. 
        scanner.close();
    }
//END OF PETGAME

    // Checks if the pet is still alive. 
    public static boolean PetStatus(int hunger, int happiness, String petName) {
        //If the hunger or happiness is zero then the pet has died. It outputs this to the user. 
        if (hunger <= 0 || happiness <= 0) {
            System.out.println(petName + " has died :(");
            //returns a boolean value of false or true to assign to "alive" variable. 
            return false;
        }
        return true;
    }
}

//END OF PETSTATUS
// Out:
// |           System.out.println("Welcome to the Pet Game!");
// <identifier> expected
//
// |           System.out.println("Welcome to the Pet Game!");
// illegal start of type
//
// |           System.out.print("Please enter your pet's name: ");
// <identifier> expected
//
// |           System.out.print("Please enter your pet's name: ");
// illegal start of type
//
// |           while (!quit && alive) {
// illegal start of type
//
// |           while (!quit && alive) {
// <identifier> expected
//
// |           while (!quit && alive) {
// <identifier> expected
//
// |           scanner.close();
// <identifier> expected

// %% [markdown]
// **END OF LITERATE DOCUMENT**
